# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load data
df = pd.read_excel('data/KCB TOWERS AND SOUTH PODIUM DATA.xlsx')

# %%
df.head()
# Out:
#              BRANCH  TOTAL  MALE  FEMALE  UNDERWEIGHT  OVERWEIGHT: BMI>25  \
# 0     KCB UPPERHILL    220    78     142            2                 101
# 1  NBK SOUTH PODIUM     23    15       8            0                  10
#
#    OBESE : BMI >30  HIGH BP  LOW HB  CHOL - HIGH  GGT - HIGH  CREA - HIGH  \
# 0               47       23       8           95          36            0
# 1                4        2       1            8           5            0
#
#    RBS - HIGH  PSA - HIGH  FOB - POSITIVE  UTI  CEA - HIGH
# 0           1           3               2    2           1
# 1           0           0               3    0           0

# %%
print(df.describe())
# Out:
#             TOTAL       MALE      FEMALE  UNDERWEIGHT  OVERWEIGHT: BMI>25  \
# count    2.000000   2.000000    2.000000     2.000000            2.000000
# mean   121.500000  46.500000   75.000000     1.000000           55.500000
# std    139.300036  44.547727   94.752309     1.414214           64.346717
# min     23.000000  15.000000    8.000000     0.000000           10.000000
# 25%     72.250000  30.750000   41.500000     0.500000           32.750000
# 50%    121.500000  46.500000   75.000000     1.000000           55.500000
# 75%    170.750000  62.250000  108.500000     1.500000           78.250000
# max    220.000000  78.000000  142.000000     2.000000          101.000000
#
#        OBESE : BMI >30    HIGH BP    LOW HB  CHOL - HIGH  GGT - HIGH  \
# count         2.000000   2.000000  2.000000      2.00000     2.00000
# mean         25.500000  12.500000  4.500000     51.50000    20.50000
# std          30.405592  14.849242  4.949747     61.51829    21.92031
# ...

# %% [markdown]
# ### KCB UPPERHILL

# %%
# Visualize data for 'KCB UPPERHILL' branch
kcb_upperhill = df[df['BRANCH'] == 'KCB UPPERHILL']

# Set style
sns.set(style="whitegrid")

# Create a color palette
palette = sns.color_palette("mako_r", len(kcb_upperhill.columns) - 2)

# Create the plot
plt.figure(figsize=(12, 8))
barplot = sns.barplot(data=kcb_upperhill.iloc[:, 2:], palette=palette)  # Exclude 'BRANCH' and 'TOTAL' columns

# Add counts on top of each bar
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.0f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', 
                     xytext = (0, 10), 
                     textcoords = 'offset points')

plt.title('Health Metrics for KCB UPPERHILL', fontsize=20)
plt.xticks(rotation=90, fontsize=12)  # Rotate x-axis labels for readability
plt.yticks(fontsize=12)
plt.xlabel(None)  # Remove x-axis label
plt.ylabel('Clients Count', fontsize=15)

# Add legend
total = kcb_upperhill['TOTAL'].values[0]
plt.legend(title=f'TOTAL CLIENTS SEEN: {total}', title_fontsize='13',loc ='upper right', bbox_to_anchor=(1.0, 0.9),
           )

# Remove top and right borders
sns.despine()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Using Ploty

# %%
import plotly.express as px

# Visualize data for 'KCB UPPERHILL' branch
kcb_upperhill = df[df['BRANCH'] == 'KCB UPPERHILL']

# Melt DataFrame to have health metrics and counts in separate columns
kcb_upperhill_melt = kcb_upperhill.melt(id_vars=['BRANCH', 'TOTAL'], var_name='Health Metric', value_name='Count')

# Create the plot
fig = px.bar(kcb_upperhill_melt, x='Health Metric', y='Count', color='Health Metric',
             title='Health Metrics for KCB UPPERHILL', labels={'Count': 'Count', 'Health Metric': ''})

# Update layout for a cleaner look
fig.update_layout(showlegend=False, plot_bgcolor='white')
fig.update_xaxes(tickangle=45, title_standoff=25)

fig.show()

# %% [markdown]
# ### NBK SOUTH PODIUM

# %%
# Visualize data for 'KCB UPPERHILL' branch
kcb_upperhill = df[df['BRANCH'] == 'NBK SOUTH PODIUM']

# Set style
sns.set(style="whitegrid")

# Create a color palette
palette = sns.color_palette("mako_r", len(kcb_upperhill.columns) - 2)

# Create the plot
plt.figure(figsize=(12, 8))
barplot = sns.barplot(data=kcb_upperhill.iloc[:, 2:], palette=palette)  # Exclude 'BRANCH' and 'TOTAL' columns

# Add counts on top of each bar
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.0f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', 
                     xytext = (0, 10), 
                     textcoords = 'offset points')

plt.title('Health Metrics for NBK SOUTH PODIUM', fontsize=20)
plt.xticks(rotation=90, fontsize=12)  # Rotate x-axis labels for readability
plt.yticks(fontsize=12)
plt.xlabel(None)  # Remove x-axis label
plt.ylabel('Clients Count', fontsize=15)

# Add legend
total = kcb_upperhill['TOTAL'].values[0]
plt.legend(title=f'TOTAL CLIENTS SEEN: {total}', title_fontsize='13',loc ='upper right', bbox_to_anchor=(1.0, 0.9),
           )

# Remove top and right borders
sns.despine()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
